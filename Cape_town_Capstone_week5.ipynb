# %% [markdown]
# <a href="https://colab.research.google.com/github/markklaaim/Capstone/blob/master/Cape_town_Capstone_week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import json
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests
import folium

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Cape_Town_suburbs'
page = urlopen(url).read().decode('utf-8')
soup = BeautifulSoup(page, 'html.parser')
my_div = soup.find('div',{'class':'mw-parser-output'})
table = soup.body.table.tbody

# %%
#get data from wikipedia
def get_cell(element):
    cells = element.find_all('td')
    row = []
    
    for cell in cells:
        if cell.a:            
            if (cell.a.text):
                row.append(cell.a.text)
                continue
        row.append(cell.string.strip())
        
    return row

def get_row():    
    data = []  
    
    for tr in table.find_all('tr'):
        row = get_cell(tr)
        if len(row) != 3:
            continue
        data.append(row)        
    
    return data

# %%
Neighborhood=[]

for items in my_div.findAll('h2')[1::1]:
    data = items.findAll(['span'])
    Neighborhood.append(data[0].text)

# %%
data_df= get_row()
columns = ['Suburb','StreetCode','PostalCode']
d = pd.DataFrame(data_df,columns=columns)
d
# Out:
#               Suburb StreetCode PostalCode
# 0            Bakoven       8005
# 1         Bantry Bay       8005
# 2            Clifton       8005
# 3           Fresnaye       8005
# 4        Green Point       8005       8051
# 5           Hout Bay       7806       7872
# 6      Imizamo Yethu       7806
# 7          Llandudno       7806
# 8      Mouille Point       8005
# 9          Sea Point       8005       8060
# 10  Three Anchor Bay       8005

# %%
dict = {'Neighborhood':Neighborhood}
kasi_df=pd.DataFrame(dict)
kasi_df
# Out:
#         Neighborhood
# 0  Atlantic Seaboard
# 1         Cape Flats
# 2          City Bowl
# 3         Helderberg
# 4   Northern Suburbs
# 5    South Peninsula
# 6   Southern Suburbs
# 7         West Coast
# 8         References

# %%
#Examining the data , its split into tables, get all and arraange
import urllib
uri1 = 'https://en.wikipedia.org/wiki/List_of_Cape_Town_suburbs'
html_table1 = urllib.request.urlopen(uri1).read()

# fix HTML
soup1 = BeautifulSoup(html_table1, "html.parser")

# %%
all_tables = soup1.find_all('table')

# %%
table1 = all_tables[0]
table2 = all_tables[1]
table3 = all_tables[2]
table4 = all_tables[3]
table5 = all_tables[4]
table6 = all_tables[5]
table7 = all_tables[6]
table8 = all_tables[7]

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table1.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}

df1=pd.DataFrame(dict)
#assign Neigbourhood
df1['Neigbourhood']='Atlantic Seaboard'

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table2.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}

df2=pd.DataFrame(dict)
df2['Neigbourhood']='Cape Flats'
df2
# Out:
#               Suburb StreetCode PostalCode Neigbourhood
# 0            Athlone       7764       7760   Cape Flats
# 1       Bishop Lavis       7490       7490   Cape Flats
# 2        Bonteheuwel       7764              Cape Flats
# 3           Crawford       7780       7770   Cape Flats
# 4         Crossroads       7755              Cape Flats
# 5              Delft       7100              Cape Flats
# 6      Electric City                         Cape Flats
# 7      Elsie's River       7490              Cape Flats
# 8             Epping       7460              Cape Flats
# 9        Grassy Park       7941       7888   Cape Flats
# 10         Gugulethu       7750              Cape Flats
# 11      Hanover Park       7780              Cape Flats
# 12  Kalksteenfontein       7490              Cape Flats
# 13       Khayelitsha       7784       7783   Cape Flats
# 14             Langa       7455       7456   Cape Flats
# 15     Lavender Hill       7945              Cape Flats
# 16       Lotus River       7941       7805   Cape Flats
# 17          Macassar       7130       7134   Cape Flats
# 18         Manenberg                         Cape Flats
# 19   Mitchells Plain       7785       7789   Cape Flats
# 20            Nyanga       7750       7755   Cape Flats
# 21            Ottery       7800       7808   Cape Flats
# 22      Pelican Park                  7941   Cape Flats
# 23          Philippi       7750              Cape Flats
# 24     Samora Machel       7785              Cape Flats
# 25     Strandfontein       7798              Cape Flats
# 26     Valhalla Park       7490              Cape Flats

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table3.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}

df3=pd.DataFrame(dict)
df3['Neigbourhood']='City Bowl'
df3
# Out:
#                                    Suburb StreetCode PostalCode Neigbourhood
# 0                 Bo-Kaap (Malay Quarter)       8001               City Bowl
# 1                     Devil's Peak Estate       8001               City Bowl
# 2                            De Waterkant       8001               City Bowl
# 3                               Foreshore       8001               City Bowl
# 4                                 Gardens       8001               City Bowl
# 5                               Higgovale       8001               City Bowl
# 6              Lower Vrede (District Six)       8001               City Bowl
# 7                             Oranjezicht       8001               City Bowl
# 8                              Salt River       7925               City Bowl
# 9                         Schotsche Kloof       8001               City Bowl
# 10                          Tamboerskloof       8001               City Bowl
# 11                      University Estate       8001               City Bowl
# 12                              Vredehoek       8001               City Bowl
# 13           Walmer Estate (District Six)       7925               City Bowl
# 14  Woodstock (including Upper Woodstock)       7925               City Bowl
# 15              Zonnebloem (District Six)       7925               City Bowl

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table4.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}

df4=pd.DataFrame(dict)
df4['Neigbourhood']='Helderberg'
df4
# Out:
#           Suburb StreetCode PostalCode Neigbourhood
# 0       Firgrove       7130       7110   Helderberg
# 1   Gordon's Bay       7140              Helderberg
# 2  Somerset West       7130       7130   Helderberg
# 3         Strand       7140       7139   Helderberg

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table5.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}


df5=pd.DataFrame(dict)
df5['Neigbourhood']='Northern Suburbs'
df5
# Out:
#            Suburb StreetCode PostalCode      Neigbourhood
# 0          Belhar       7493             Northern Suburbs
# 1       Bellville       7530             Northern Suburbs
# 2     Brackenfell       7560             Northern Suburbs
# 3        Bothasig       7441             Northern Suburbs
# 4        Brooklyn       7405       7420  Northern Suburbs
# 5     Durbanville       7550       7551  Northern Suburbs
# 6        Edgemead       7441             Northern Suburbs
# 7   Elsie's River       7490             Northern Suburbs
# 8        Goodwood       7460       7459  Northern Suburbs
# 9      Kensington       7405             Northern Suburbs
# 10   Kraaifontein       7570       7572  Northern Suburbs
# 11    Kuils River       7579       7580  Northern Suburbs
# 12    Loevenstein       7530             Northern Suburbs
# 13       Maitland       7405       7404  Northern Suburbs
# 14      Milnerton       7605       7404  Northern Suburbs
# 15    Monte Vista       7460       7463  Northern Suburbs
# 16       Panorama       7500       7506  Northern Suburbs
# 17          Parow       7500       7499  Northern Suburbs
# 18    Plattekloof       7500             Northern Suburbs
# 19          Rugby       7405             Northern Suburbs
# 20       Thornton       7460       7485  Northern Suburbs

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table6.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}

df6=pd.DataFrame(dict)
df6['Neigbourhood']='South Peninsula'
df6
# Out:
#                          Suburb StreetCode PostalCode     Neigbourhood
# 0                 Capri Village       7975             South Peninsula
# 1                      Clovelly       7975             South Peninsula
# 2                     Fish Hoek       7975       7974  South Peninsula
# 3                     Glencairn       7975             South Peninsula
# 4                      Kalk Bay       7975       7990  South Peninsula
# 5                     Kommetjie       7975       7976  South Peninsula
# 6                      Lakeside       7945       7946  South Peninsula
# 7                Marina da Gama       7945             South Peninsula
# 8                 Masiphumelele       7975             South Peninsula
# 9                    Muizenberg       7945       7950  South Peninsula
# 10    Noordhoek (PO boxes only)                  7979  South Peninsula
# 11                   Ocean View       7975             South Peninsula
# 12  Scarborough (PO boxes only)                  7975  South Peninsula
# 13                 Simon's Town       7975       7995  South Peninsula
# 14                     St James       7945       7946  South Peninsula
# 15                    Sunnydale       7975             South Peninsula
# 16                   Sun Valley       7975       7985  South Peninsula

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table7.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}

df7=pd.DataFrame(dict)
df7['Neigbourhood']='Southern Suburbs'
df7
# Out:
#               Suburb StreetCode PostalCode      Neigbourhood
# 0          Bergvliet       7945       7864  Southern Suburbs
# 1       Bishopscourt       7708             Southern Suburbs
# 2          Claremont       7708       7735  Southern Suburbs
# 3         Constantia       7806    7848[1]  Southern Suburbs
# 4         Diep River       7945       7800  Southern Suburbs
# 5   Harfield Village       7708             Southern Suburbs
# 6         Heathfield       7945             Southern Suburbs
# 7         Kenilworth       7708       7745  Southern Suburbs
# 8             Kenwyn       7780             Southern Suburbs
# 9         Kirstenhof       7945             Southern Suburbs
# 10      Kreupelbosch       7806             Southern Suburbs
# 11         Lansdowne       7780       7779  Southern Suburbs
# 12       Meadowridge       7806             Southern Suburbs
# 13           Mowbray       7700       7705  Southern Suburbs
# 14           Ndabeni       7405             Southern Suburbs
# 15          Newlands       7700       7725  Southern Suburbs
# 16       Observatory       7925       7935  Southern Suburbs
# 17         Pinelands       7405       7430  Southern Suburbs
# 18         Plumstead       7800       7801  Southern Suburbs
# 19           Retreat       7945       7965  Southern Suburbs
# 20        Rondebosch       7700       7701  Southern Suburbs
# 21   Rondebosch East       7780             Southern Suburbs
# 22          Rosebank       7700             Southern Suburbs
# 23        SouthField       7880             Southern Suburbs
# 24         Steenberg       7945             Southern Suburbs
# 25             Tokai       7945       7966  Southern Suburbs
# 26           Wynberg       7800       7824  Southern Suburbs

# %%
Suburb=[]
StreetCode=[]
PostalCode=[]

for items in table8.findAll('tr')[1::1]:
    data = items.findAll(['td'])
    Suburb.append(data[0].text)
    StreetCode.append(data[1].text)
    PostalCode.append(data[2].text.rstrip())
    
dict = {'Suburb':Suburb,'StreetCode':StreetCode,'PostalCode':PostalCode}

df8=pd.DataFrame(dict)
df8['Neigbourhood']='West Coast'
df8
# Out:
#              Suburb StreetCode PostalCode Neigbourhood
# 0          Atlantis       7349       7349   West Coast
# 1    Bloubergstrand       7441       7441   West Coast
# 2           Darling       7345       7345   West Coast
# 3             Mamre       7349       7349   West Coast
# 4     Melkbosstrand       7441       7441   West Coast
# 5         Milnerton       7441       7435   West Coast
# 6  Montague Gardens       7441       7441   West Coast
# 7         Parklands       7441       7441   West Coast
# 8        Table View       7441       7439   West Coast
# 9        West Beach       7441       7441   West Coast

# %%
#merge df
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8], ignore_index=True)
df
# Out:
#                Suburb StreetCode PostalCode       Neigbourhood
# 0             Bakoven       8005             Atlantic Seaboard
# 1          Bantry Bay       8005             Atlantic Seaboard
# 2           Camps Bay       8005       8040  Atlantic Seaboard
# 3             Clifton       8005             Atlantic Seaboard
# 4            Fresnaye       8005             Atlantic Seaboard
# ..                ...        ...        ...                ...
# 129         Milnerton       7441       7435         West Coast
# 130  Montague Gardens       7441       7441         West Coast
# 131         Parklands       7441       7441         West Coast
# 132        Table View       7441       7439         West Coast
# 133        West Beach       7441       7441         West Coast
#
# [134 rows x 4 columns]

# %%
df = df[df.StreetCode != '']

# %%
df.head()
# Out:
#        Suburb StreetCode PostalCode       Neigbourhood
# 0     Bakoven       8005             Atlantic Seaboard
# 1  Bantry Bay       8005             Atlantic Seaboard
# 2   Camps Bay       8005       8040  Atlantic Seaboard
# 3     Clifton       8005             Atlantic Seaboard
# 4    Fresnaye       8005             Atlantic Seaboard

# %%
df_group_streets=df.groupby('StreetCode').agg(lambda x: set(x)).reset_index()
df_group_streets
# Out:
#    StreetCode  ...                                     Neigbourhood
# 0        7100  ...                                     {Cape Flats}
# 1        7130  ...                         {Cape Flats, Helderberg}
# 2        7140  ...                                     {Helderberg}
# 3        7345  ...                                     {West Coast}
# 4        7349  ...                                     {West Coast}
# 5        7405  ...             {Southern Suburbs, Northern Suburbs}
# 6        7441  ...                   {Northern Suburbs, West Coast}
# 7        7455  ...                                     {Cape Flats}
# 8        7460  ...                   {Cape Flats, Northern Suburbs}
# 9        7490  ...                   {Cape Flats, Northern Suburbs}
# 10       7493  ...                               {Northern Suburbs}
# 11       7500  ...                               {Northern Suburbs}
# 12       7530  ...                               {Northern Suburbs}
# 13       7550  ...                               {Northern Suburbs}
# 14       7560  ...                               {Northern Suburbs}
# 15       7570  ...                               {Northern Suburbs}
# 16       7579  ...                               {Northern Suburbs}
# 17       7605  ...                               {Northern Suburbs}
# 18       7700  ...                               {Southern Suburbs}
# 19       7708  ...                               {Southern Suburbs}
# 20       7750  ...                                     {Cape Flats}
# 21       7755  ...                                     {Cape Flats}
# 22       7764  ...                                     {Cape Flats}
# 23       7780  ...                   {Cape Flats, Southern Suburbs}
# 24       7784  ...                                     {Cape Flats}
# 25       7785  ...                                     {Cape Flats}
# 26       7798  ...                                     {Cape Flats}
# 27       7800  ...                   {Cape Flats, Southern Suburbs}
# 28       7806  ...            {Southern Suburbs, Atlantic Seaboard}
# 29       7880  ...                               {Southern Suburbs}
# 30       7925  ...                    {City Bowl, Southern Suburbs}
# 31       7941  ...                                     {Cape Flats}
# 32       7945  ...  {Cape Flats, South Peninsula, Southern Suburbs}
# 33       7975  ...                                {South Peninsula}
# 34       8001  ...                                      {City Bowl}
# 35       8005  ...                              {Atlantic Seaboard}
#
# [36 rows x 4 columns]

# %%
#import libaries and mapping
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# %%
address = 'Cape Town, CPT'

geolocator = Nominatim(user_agent="cpt_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the City Of Cape Town are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of the City Of Cape Town are -33.928992, 18.417396.

# %%
geo = pd.read_csv('/content/geospatial_data_cape_town.csv')
geo.head()
# Out:
#    Street Code   Latitude  Longitude
# 0         7100  52.011578   4.357068
# 1         7130  34.055090  18.789030
# 2         7140 -34.604591  19.392450
# 3         7349 -33.513000  18.474910
# 4         7405 -30.340990  30.120939

# %%
geo = geo.rename(columns={'Street Code': 'StreetCode'})

# %%
geo.dtypes
# Out:
# StreetCode      int64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
geo['StreetCode'].astype(object)
# Out:
# 0     7100
# 1     7130
# 2     7140
# 3     7349
# 4     7405
# 5     7441
# 6     7455
# 7     7460
# 8     7490
# 9     7493
# 10    7500
# 11    7530
# 12    7550
# 13    7560
# 14    7570
# 15    7579
# 16    7605
# 17    7700
# 18    7708
# 19    7750
# 20    7764
# 21    7780
# 22    7784
# 23    7785
# 24    7798
# 25    7800
# 26    7806
# 27    7880
# 28    7925
# 29    7941
# 30    7945
# 31    7975
# 32    8001
# 33    8005
# Name: StreetCode, dtype: object

# %%
df.dtypes
geo['StreetCode'] = geo['StreetCode'].apply(lambda x: str(x))

# %%
geo.StreetCode.astype(object)
# Out:
# 0     7100
# 1     7130
# 2     7140
# 3     7349
# 4     7405
# 5     7441
# 6     7455
# 7     7460
# 8     7490
# 9     7493
# 10    7500
# 11    7530
# 12    7550
# 13    7560
# 14    7570
# 15    7579
# 16    7605
# 17    7700
# 18    7708
# 19    7750
# 20    7764
# 21    7780
# 22    7784
# 23    7785
# 24    7798
# 25    7800
# 26    7806
# 27    7880
# 28    7925
# 29    7941
# 30    7945
# 31    7975
# 32    8001
# 33    8005
# Name: StreetCode, dtype: object

# %%
df_group_streets = pd.merge(df, geo, on='StreetCode')
df_group_streets.head()
# Out:
#        Suburb StreetCode PostalCode       Neigbourhood  Latitude  Longitude
# 0     Bakoven       8005             Atlantic Seaboard -33.91963   18.38568
# 1  Bantry Bay       8005             Atlantic Seaboard -33.91963   18.38568
# 2   Camps Bay       8005       8040  Atlantic Seaboard -33.91963   18.38568
# 3     Clifton       8005             Atlantic Seaboard -33.91963   18.38568
# 4    Fresnaye       8005             Atlantic Seaboard -33.91963   18.38568

# %%
# create map 
map_of_cape_town= folium.Map(location=[latitude, longitude], zoom_start=12)
  
    
# add markers to map
for lat,lang, Suburb, neighborhood in zip(df_group_streets['Latitude'],df_group_streets['Longitude'], df_group_streets['Suburb'], df_group_streets['Neigbourhood']):
    label = '{}, {}'.format(neighborhood, Suburb)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat,lang],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_of_cape_town)
    
map_of_cape_town
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML

# %%
CLIENT_ID = 'KYANQMANEUJ33G0KT0J5HZRC03IKLZ1WFBR4V334H4PEHVDM' # your Foursquare ID
CLIENT_SECRET = 'ZN0LNIWH3GHLSA2LDBU1TRSNDPFVBFNRRLYNSIYOM4GXSXR5' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 30
print(' credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
#  credentails:
# CLIENT_ID: KYANQMANEUJ33G0KT0J5HZRC03IKLZ1WFBR4V334H4PEHVDM
# CLIENT_SECRET:ZN0LNIWH3GHLSA2LDBU1TRSNDPFVBFNRRLYNSIYOM4GXSXR5

# %%
df_group_streets.loc[0, 'Neigbourhood']
# Out:
# 'Atlantic Seaboard'

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
cape_town_venues = getNearbyVenues(names=df_group_streets['Neigbourhood'],
                                   latitudes=df_group_streets['Latitude'],
                                   longitudes=df_group_streets['Longitude']
                                  )
# Out:
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Atlantic Seaboard
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# Northern Suburbs
# Cape Flats
# Cape Flats
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Cape Flats
# Cape Flats
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# Cape Flats
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Cape Flats
# Helderberg
# Helderberg
# Cape Flats
# Cape Flats
# Cape Flats
# Southern Suburbs
# Southern Suburbs
# Cape Flats
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# City Bowl
# Southern Suburbs
# Helderberg
# Helderberg
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# West Coast
# West Coast
# West Coast
# West Coast
# West Coast
# West Coast
# West Coast
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Southern Suburbs
# Southern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# Northern Suburbs
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# South Peninsula
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# Southern Suburbs
# West Coast
# West Coast

# %%
print(cape_town_venues.shape)
cape_town_venues.head()
# Out:
# (1005, 7)
#         Neighborhood  Neighborhood Latitude  ...  Venue Longitude     Venue Category
# 0  Atlantic Seaboard              -33.91963  ...        18.386617     Ice Cream Shop
# 1  Atlantic Seaboard              -33.91963  ...        18.385418        Coffee Shop
# 2  Atlantic Seaboard              -33.91963  ...        18.385484             Market
# 3  Atlantic Seaboard              -33.91963  ...        18.385641              Hotel
# 4  Atlantic Seaboard              -33.91963  ...        18.382778  French Restaurant
#
# [5 rows x 7 columns]

# %%
cape_town_venues.groupby('Neighborhood').count()
# Out:
#                    Neighborhood Latitude  ...  Venue Category
# Neighborhood                              ...
# Atlantic Seaboard                    306  ...             306
# Cape Flats                            74  ...              74
# City Bowl                            220  ...             220
# Helderberg                             4  ...               4
# Northern Suburbs                      54  ...              54
# South Peninsula                      166  ...             166
# Southern Suburbs                     174  ...             174
# West Coast                             7  ...               7
#
# [8 rows x 6 columns]

# %%
#### Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(cape_town_venues['Venue Category'].unique())))
# Out:
# There are 75 uniques categories.

# %%
## 3. Analyze Each Neighborhood

# %%
# one hot encoding
cape_town_onehot = pd.get_dummies(cape_town_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
cape_town_onehot['Neighborhood'] = cape_town_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [cape_town_onehot.columns[-1]] + list(cape_town_onehot.columns[:-1])
cape_town_onehot = cape_town_onehot[fixed_columns]

cape_town_onehot.head()
# Out:
#         Neighborhood  African Restaurant  ...  Thai Restaurant  Wine Bar
# 0  Atlantic Seaboard                   0  ...                0         0
# 1  Atlantic Seaboard                   0  ...                0         0
# 2  Atlantic Seaboard                   0  ...                0         0
# 3  Atlantic Seaboard                   0  ...                0         0
# 4  Atlantic Seaboard                   0  ...                0         0
#
# [5 rows x 76 columns]

# %%
cape_town_onehot.shape
# Out:
# (1005, 76)

# %%
cape_town_grouped = cape_town_onehot.groupby('Neighborhood').mean().reset_index()
cape_town_grouped
# Out:
#         Neighborhood  African Restaurant  ...  Thai Restaurant  Wine Bar
# 0  Atlantic Seaboard            0.000000  ...         0.000000  0.000000
# 1         Cape Flats            0.000000  ...         0.013514  0.000000
# 2          City Bowl            0.018182  ...         0.000000  0.000000
# 3         Helderberg            0.000000  ...         0.000000  0.000000
# 4   Northern Suburbs            0.000000  ...         0.018519  0.000000
# 5    South Peninsula            0.000000  ...         0.000000  0.000000
# 6   Southern Suburbs            0.005747  ...         0.022989  0.022989
# 7         West Coast            0.000000  ...         0.000000  0.000000
#
# [8 rows x 76 columns]

# %%
cape_town_grouped.shape
# Out:
# (8, 76)

# %%
num_top_venues = 5

for hood in cape_town_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = cape_town_grouped[cape_town_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Atlantic Seaboard----
#            venue  freq
# 0    Coffee Shop  0.11
# 1  Grocery Store  0.08
# 2          Hotel  0.06
# 3           Café  0.06
# 4       Pharmacy  0.04
#
#
# ----Cape Flats----
#                venue  freq
# 0        Gas Station  0.14
# 1               Café  0.09
# 2        Pizza Place  0.05
# 3  Convenience Store  0.05
# 4           Pharmacy  0.04
#
#
# ----City Bowl----
#                   venue  freq
# 0                 Hotel  0.22
# 1           Coffee Shop  0.15
# 2                  Park  0.05
# 3                   Bar  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----Helderberg----
#                 venue  freq
# 0   Convenience Store   0.5
# 1               Beach   0.5
# 2  African Restaurant   0.0
# 3           Jazz Club   0.0
# 4         Music Venue   0.0
#
#
# ----Northern Suburbs----
#                   venue  freq
# 0         Grocery Store  0.11
# 1        Breakfast Spot  0.09
# 2  Fast Food Restaurant  0.09
# 3                   Pub  0.07
# 4        Cricket Ground  0.06
#
#
# ----South Peninsula----
#                   venue  freq
# 0    Seafood Restaurant  0.20
# 1         Grocery Store  0.13
# 2           Pizza Place  0.07
# 3  Fast Food Restaurant  0.07
# 4     Indian Restaurant  0.07
#
#
# ----Southern Suburbs----
#                venue  freq
# 0        Coffee Shop  0.09
# 1               Park  0.06
# 2         Steakhouse  0.06
# 3        Pizza Place  0.06
# 4  Convenience Store  0.05
#
#
# ----West Coast----
#                 venue  freq
# 0   Fish & Chips Shop   1.0
# 1  African Restaurant   0.0
# 2  Italian Restaurant   0.0
# 3         Music Venue   0.0
# 4  Mexican Restaurant   0.0

# %%
#### put that into a *pandas* dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = cape_town_grouped['Neighborhood']

for ind in np.arange(cape_town_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(cape_town_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#         Neighborhood  ... 10th Most Common Venue
# 0  Atlantic Seaboard  ...               Pharmacy
# 1         Cape Flats  ...     Italian Restaurant
# 2          City Bowl  ...                   Café
# 3         Helderberg  ...               Wine Bar
# 4   Northern Suburbs  ...             Steakhouse
#
# [5 rows x 11 columns]

# %%
## 4. Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

cape_town_grouped_clustering = cape_town_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cape_town_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 4, 2, 1, 3, 1, 0], dtype=int32)

# %%
cape_town_merged = df_group_streets

# merge cape_town_grouped with df_group_streets to add latitude/longitude for each neighborhood
cape_town_merged = cape_town_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neigbourhood')

cape_town_merged.head() # check the last columns!
# Out:
#        Suburb StreetCode  ... 9th Most Common Venue 10th Most Common Venue
# 0     Bakoven       8005  ...    Italian Restaurant               Pharmacy
# 1  Bantry Bay       8005  ...    Italian Restaurant               Pharmacy
# 2   Camps Bay       8005  ...    Italian Restaurant               Pharmacy
# 3     Clifton       8005  ...    Italian Restaurant               Pharmacy
# 4    Fresnaye       8005  ...    Italian Restaurant               Pharmacy
#
# [5 rows x 17 columns]

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(cape_town_merged['Latitude'], cape_town_merged['Longitude'], cape_town_merged['Neigbourhood'], cape_town_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#cluster 1

# %%
cape_town_merged.loc[cape_town_merged['Cluster Labels'] == 1, cape_town_merged.columns[[3] + list(range(5, cape_town_merged.shape[1]))]]
# Out:
#           Neigbourhood  Longitude  ...  9th Most Common Venue 10th Most Common Venue
# 0    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 1    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 2    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 3    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 4    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# ..                 ...        ...  ...                    ...                    ...
# 120   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 121   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 122   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 123   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 124   Southern Suburbs   18.48541  ...            Flea Market                    Bar
#
# [83 rows x 13 columns]

# %%
#cluster 2

# %%
cape_town_merged.loc[cape_town_merged['Cluster Labels'] == 1, cape_town_merged.columns[[3] + list(range(5, cape_town_merged.shape[1]))]]
# Out:
#           Neigbourhood  Longitude  ...  9th Most Common Venue 10th Most Common Venue
# 0    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 1    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 2    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 3    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# 4    Atlantic Seaboard   18.38568  ...     Italian Restaurant               Pharmacy
# ..                 ...        ...  ...                    ...                    ...
# 120   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 121   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 122   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 123   Southern Suburbs   18.49798  ...            Flea Market                    Bar
# 124   Southern Suburbs   18.48541  ...            Flea Market                    Bar
#
# [83 rows x 13 columns]

# %%
#Cluster 3

# %%
cape_town_merged.loc[cape_town_merged['Cluster Labels'] == 2, cape_town_merged.columns[[3] + list(range(5, cape_town_merged.shape[1]))]]
# Out:
#    Neigbourhood  Longitude  ...  9th Most Common Venue 10th Most Common Venue
# 52   Helderberg   18.78903  ...          Deli / Bodega               Wine Bar
# 53   Helderberg   18.78903  ...          Deli / Bodega               Wine Bar
# 77   Helderberg   19.39245  ...          Deli / Bodega               Wine Bar
# 78   Helderberg   19.39245  ...          Deli / Bodega               Wine Bar
#
# [4 rows x 13 columns]

# %%
#Cluster 4

# %%
cape_town_merged.loc[cape_town_merged['Cluster Labels'] == 3, cape_town_merged.columns[[3] + list(range(5, cape_town_merged.shape[1]))]]
# Out:
#         Neigbourhood  Longitude  ...  9th Most Common Venue 10th Most Common Venue
# 40   South Peninsula   18.47423  ...                    Bar                  Beach
# 41   South Peninsula   18.47423  ...                    Bar                  Beach
# 42   South Peninsula   18.47423  ...                    Bar                  Beach
# 43   South Peninsula   18.47423  ...                    Bar                  Beach
# 105  South Peninsula   18.43036  ...                    Bar                  Beach
# 106  South Peninsula   18.43036  ...                    Bar                  Beach
# 107  South Peninsula   18.43036  ...                    Bar                  Beach
# 108  South Peninsula   18.43036  ...                    Bar                  Beach
# 109  South Peninsula   18.43036  ...                    Bar                  Beach
# 110  South Peninsula   18.43036  ...                    Bar                  Beach
# 111  South Peninsula   18.43036  ...                    Bar                  Beach
# 112  South Peninsula   18.43036  ...                    Bar                  Beach
# 113  South Peninsula   18.43036  ...                    Bar                  Beach
# 114  South Peninsula   18.43036  ...                    Bar                  Beach
# 115  South Peninsula   18.43036  ...                    Bar                  Beach
#
# [15 rows x 13 columns]

# %%
#Cluster 5

# %%
cape_town_merged.loc[cape_town_merged['Cluster Labels'] == 4, cape_town_merged.columns[[3] + list(range(5, cape_town_merged.shape[1]))]]
# Out:
#    Neigbourhood  Longitude  ...  9th Most Common Venue 10th Most Common Venue
# 60    City Bowl   18.41590  ...           Burger Joint                   Café
# 61    City Bowl   18.41590  ...           Burger Joint                   Café
# 62    City Bowl   18.41590  ...           Burger Joint                   Café
# 63    City Bowl   18.41590  ...           Burger Joint                   Café
# 64    City Bowl   18.41590  ...           Burger Joint                   Café
# 65    City Bowl   18.41590  ...           Burger Joint                   Café
# 66    City Bowl   18.41590  ...           Burger Joint                   Café
# 67    City Bowl   18.41590  ...           Burger Joint                   Café
# 68    City Bowl   18.41590  ...           Burger Joint                   Café
# 69    City Bowl   18.41590  ...           Burger Joint                   Café
# 70    City Bowl   18.41590  ...           Burger Joint                   Café
# 71    City Bowl   18.41590  ...           Burger Joint                   Café
# 72    City Bowl   18.46737  ...           Burger Joint                   Café
# 73    City Bowl   18.46737  ...           Burger Joint                   Café
# 74    City Bowl   18.46737  ...           Burger Joint                   Café
# 75    City Bowl   18.46737  ...           Burger Joint                   Café
#
# [16 rows x 13 columns]

# %%
#In Cape town neighbourhoods are defined by street codes , so we want to examine the 7550 and 7708 neighbourhoods which are close by.
khayelitsha_data = df_group_streets[df_group_streets['StreetCode'] == '7550'].reset_index(drop=True)
khayelitsha_data.head()

neighborhood_latitude = khayelitsha_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = khayelitsha_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = khayelitsha_data.loc[0, 'Neigbourhood'] # neighborhood area

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Northern Suburbs are -33.830090000000006, 18.64679.

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    neighborhood_latitude,
    neighborhood_longitude,
    500,
    100
    
)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ed3f7f69388d7001bff66e3'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f0d6c0de4b01660dc7720d1-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4f0d6c0de4b01660dc7720d1',
#        'location': {'address': 'Durban Rd',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Vrede St',
#         'distance': 228,
#         'formattedAddress': ['Durban Rd (Vrede St)',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83209368358392,
#           'lng': 18.646245724366526}],
#         'lat': -33.83209368358392,
#         'lng': 18.646245724366526,
#         'state': 'Western Cape'},
#        'name': "D's Speakeasy",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54a8ff61498ea66986616438-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '54a8ff61498ea66986616438',
#        'location': {'address': 'Oxford',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Wellington',
#         'distance': 173,
#         'formattedAddress': ['Oxford (Wellington)',
#          'Durbanville',
#          '7550',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83064109948833,
#           'lng': 18.6485429499513}],
#         'lat': -33.83064109948833,
#         'lng': 18.6485429499513,
#         'postalCode': '7550',
#         'state': 'Western Cape'},
#        'name': 'Vida e café',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c1b5218013795210ddb46f3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e5931735',
#          'name': 'Music Venue',
#          'pluralName': 'Music Venues',
#          'primary': True,
#          'shortName': 'Music Venue'}],
#        'id': '4c1b5218013795210ddb46f3',
#        'location': {'address': 'Chenoweth',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Wellington',
#         'distance': 345,
#         'formattedAddress': ['Chenoweth (Wellington)',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.830183572547405,
#           'lng': 18.6505284571695}],
#         'lat': -33.830183572547405,
#         'lng': 18.6505284571695,
#         'state': 'Western Cape'},
#        'name': 'Die Boer',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c1de818b306c928534866b7-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '4c1de818b306c928534866b7',
#        'location': {'address': '6 Marais Crescent',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 445,
#         'formattedAddress': ['6 Marais Crescent',
#          'Durbanville',
#          '7550',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83008157677166,
#           'lng': 18.651610845286047}],
#         'lat': -33.83008157677166,
#         'lng': 18.651610845286047,
#         'postalCode': '7550',
#         'state': 'Western Cape'},
#        'name': 'Cattle Baron',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-509631b1e4b0cb1b32536eb7-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'primary': True,
#          'shortName': 'Gastropub'}],
#        'id': '509631b1e4b0cb1b32536eb7',
#        'location': {'address': 'Queenstreet',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Durban Rd',
#         'distance': 479,
#         'formattedAddress': ['Queenstreet (Durban Rd)',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83118824137428,
#           'lng': 18.651800219788324}],
#         'lat': -33.83118824137428,
#         'lng': 18.651800219788324,
#         'state': 'Western Cape'},
#        'name': 'The Olive Bistro',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f87eaa7e4b05ae887639584-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4f87eaa7e4b05ae887639584',
#        'location': {'address': 'Oxford Street',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 170,
#         'formattedAddress': ['Oxford Street',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83061660787478,
#           'lng': 18.648525552691485}],
#         'lat': -33.83061660787478,
#         'lng': 18.648525552691485,
#         'state': 'Western Cape'},
#        'name': 'Soet',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d6bccaa87b9548100cdc5dd-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '4d6bccaa87b9548100cdc5dd',
#        'location': {'address': '25 Wellington Road',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 259,
#         'formattedAddress': ['25 Wellington Road',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.82946538513488,
#           'lng': 18.64949452333092}],
#         'lat': -33.82946538513488,
#         'lng': 18.64949452333092,
#         'state': 'Western Cape'},
#        'name': 'Bossa Nova',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be9a0a8a9900f479f8d1540-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '4be9a0a8a9900f479f8d1540',
#        'location': {'address': 'Cnr King and New Streets',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 436,
#         'formattedAddress': ['Cnr King and New Streets',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.82647111693134,
#           'lng': 18.64860625666377}],
#         'lat': -33.82647111693134,
#         'lng': 18.64860625666377,
#         'state': 'Western Cape'},
#        'name': "Alberto's Restaurant and Pub",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c45cc57f799e21eaab0afa2-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'primary': True,
#          'shortName': 'Breakfast'}],
#        'id': '4c45cc57f799e21eaab0afa2',
#        'location': {'address': 'Cnr Voortrekker Rd & Wellington Rd',
#         'cc': 'ZA',
#         'city': 'iKapa',
#         'country': 'iNingizimu Afrika',
#         'distance': 293,
#         'formattedAddress': ['Cnr Voortrekker Rd & Wellington Rd',
#          'iKapa',
#          '7550',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83266883428387,
#           'lng': 18.6474581940829}],
#         'lat': -33.83266883428387,
#         'lng': 18.6474581940829,
#         'postalCode': '7550',
#         'state': 'Western Cape'},
#        'name': 'Silver Creek Spur',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d13181affa1224b3ff59dad-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'primary': True,
#          'shortName': 'Gym'}],
#        'id': '4d13181affa1224b3ff59dad',
#        'location': {'address': 'Deville Centre',
#         'cc': 'ZA',
#         'city': 'iKapa',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Main Rd.',
#         'distance': 167,
#         'formattedAddress': ['Deville Centre (Main Rd.)',
#          'iKapa',
#          '7550',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.831549399923496,
#           'lng': 18.64723235867574}],
#         'lat': -33.831549399923496,
#         'lng': 18.64723235867574,
#         'postalCode': '7550',
#         'state': 'Western Cape'},
#        'name': 'Virgin Active Health Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be1a45542e8c928fa783406-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4be1a45542e8c928fa783406',
#        'location': {'address': 'Main Road',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Church Street',
#         'distance': 422,
#         'formattedAddress': ['Main Road (Church Street)',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83378313206032,
#           'lng': 18.647833639496014}],
#         'lat': -33.83378313206032,
#         'lng': 18.647833639496014,
#         'state': 'Western Cape'},
#        'name': 'Woolworths Palm Grove',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5256f5a211d2857ca3662556-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'primary': True,
#          'shortName': 'Steakhouse'}],
#        'id': '5256f5a211d2857ca3662556',
#        'location': {'address': 'Unit 1 Ground Floor',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Heritage Square',
#         'distance': 318,
#         'formattedAddress': ['Unit 1 Ground Floor (Heritage Square)',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83292198978405,
#           'lng': 18.646268665951144}],
#         'lat': -33.83292198978405,
#         'lng': 18.646268665951144,
#         'state': 'Western Cape'},
#        'name': 'Slug And Lettuce',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4edcf3987ee5e8e3e9db39a7-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'primary': True,
#          'shortName': 'Sports Bar'}],
#        'id': '4edcf3987ee5e8e3e9db39a7',
#        'location': {'address': 'Wellington Road',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 273,
#         'formattedAddress': ['Wellington Road',
#          'Durbanville',
#          '7550',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.82953206671463,
#           'lng': 18.649671840572978}],
#         'lat': -33.82953206671463,
#         'lng': 18.649671840572978,
#         'postalCode': '7550',
#         'state': 'Western Cape'},
#        'name': 'Bella Bellota Durbanville',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d1ca104c17ff04d1230c841-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '4d1ca104c17ff04d1230c841',
#        'location': {'address': 'Wellington Road',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 129,
#         'formattedAddress': ['Wellington Road',
#          'Durbanville',
#          '7550',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83094287365553,
#           'lng': 18.647743287291053}],
#         'lat': -33.83094287365553,
#         'lng': 18.647743287291053,
#         'postalCode': '7550',
#         'state': 'Western Cape'},
#        'name': 'Checkers Durbanville',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bcec422cc8cd13aecd1c4cf-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4bcec422cc8cd13aecd1c4cf',
#        'location': {'address': '33 Oxford Rd',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 94,
#         'formattedAddress': ['33 Oxford Rd',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83042095098909,
#           'lng': 18.647732299566467}],
#         'lat': -33.83042095098909,
#         'lng': 18.647732299566467,
#         'state': 'Western Cape'},
#        'name': 'Chocolat Café Decor',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e9ac9fa4901d3b0b70dbf86-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'primary': True,
#          'shortName': 'Burgers'}],
#        'id': '4e9ac9fa4901d3b0b70dbf86',
#        'location': {'address': 'Shop 03 De Ville Shopping Centre, Corner Wellington and Main Road, Durbanville',
#         'cc': 'ZA',
#         'city': 'iKapa',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'De Ville Centre',
#         'distance': 153,
#         'formattedAddress': ['Shop 03 De Ville Shopping Centre, Corner Wellington and Main Road, Durbanville (De Ville Centre)',
#          'iKapa',
#          '7551',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.831468,
#           'lng': 18.646806}],
#         'lat': -33.831468,
#         'lng': 18.646806,
#         'postalCode': '7551',
#         'state': 'Western Cape'},
#        'name': 'Wimpy',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d4543191928a35d0597c170-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4d4543191928a35d0597c170',
#        'location': {'address': '18 Wellington Road',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 251,
#         'formattedAddress': ['18 Wellington Road',
#          'Durbanville',
#          '7551',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.8303,
#           'lng': 18.6495}],
#         'lat': -33.8303,
#         'lng': 18.6495,
#         'postalCode': '7551',
#         'state': 'Western Cape'},
#        'name': 'KFC',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dde780688779c82bec4fbe6-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '4dde780688779c82bec4fbe6',
#        'location': {'cc': 'ZA',
#         'city': 'iKapa',
#         'country': 'iNingizimu Afrika',
#         'distance': 254,
#         'formattedAddress': ['iKapa', 'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83230550518704,
#           'lng': 18.646108200688076}],
#         'lat': -33.83230550518704,
#         'lng': 18.646108200688076,
#         'state': 'Western Cape'},
#        'name': 'Simply Asia Durbanville',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c7e2c3fd461a143ae2d7ff5-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4c7e2c3fd461a143ae2d7ff5',
#        'location': {'address': 'Shop 12A, Palm Grove Centre, Main & Church Streets, Durbanville',
#         'cc': 'ZA',
#         'city': 'iKapa',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Durbanville Ave.',
#         'distance': 408,
#         'formattedAddress': ['Shop 12A, Palm Grove Centre, Main & Church Streets, Durbanville (Durbanville Ave.)',
#          'iKapa',
#          '7551',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.8336878,
#           'lng': 18.6476441}],
#         'lat': -33.8336878,
#         'lng': 18.6476441,
#         'postalCode': '7551',
#         'state': 'Western Cape'},
#        'name': 'Mugg & Bean',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5256fd71498ec65c3ea54bc1-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d154941735',
#          'name': 'Cuban Restaurant',
#          'pluralName': 'Cuban Restaurants',
#          'primary': True,
#          'shortName': 'Cuban'}],
#        'id': '5256fd71498ec65c3ea54bc1',
#        'location': {'address': 'Palm Grove Centre',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'distance': 414,
#         'formattedAddress': ['Palm Grove Centre',
#          'Durbanville',
#          '7550',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.833696085905466,
#           'lng': 18.647910850037945}],
#         'lat': -33.833696085905466,
#         'lng': 18.647910850037945,
#         'postalCode': '7550',
#         'state': 'Western Cape'},
#        'name': 'Buena Vista Social Café',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b9e7349f964a520ece436e3-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4b9e7349f964a520ece436e3',
#        'location': {'address': 'Main rd',
#         'cc': 'ZA',
#         'city': 'Durbanville',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Wellington rd',
#         'distance': 269,
#         'formattedAddress': ['Main rd (Wellington rd)',
#          'Durbanville',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.832498,
#           'lng': 18.646523}],
#         'lat': -33.832498,
#         'lng': 18.646523,
#         'state': 'Western Cape'},
#        'name': "Roman's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fad2ae6e4b09c3c7275a572-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '4fad2ae6e4b09c3c7275a572',
#        'location': {'address': 'Palm Grove Centre',
#         'cc': 'ZA',
#         'country': 'iNingizimu Afrika',
#         'crossStreet': 'Stones Durbanville',
#         'distance': 435,
#         'formattedAddress': ['Palm Grove Centre (Stones Durbanville)',
#          'iNingizimu Afrika'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -33.83388805028552,
#           'lng': 18.647939845423114}],
#         'lat': -33.83388805028552,
#         'lng': 18.647939845423114},
#        'name': 'Himalayan Asian Restaurant,Sushi Bar and Lounge',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Durbanville, Cape Town',
#   'headerLocation': 'Durbanville',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': -33.8255899955, 'lng': 18.65219705985775},
#    'sw': {'lat': -33.83459000450001, 'lng': 18.64138294014225}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 22}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
from pandas.io.json import json_normalize
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#                name   categories        lat        lng
# 0     D's Speakeasy          Pub -33.832094  18.646246
# 1       Vida e café         Café -33.830641  18.648543
# 2          Die Boer  Music Venue -33.830184  18.650528
# 3      Cattle Baron   Steakhouse -33.830082  18.651611
# 4  The Olive Bistro    Gastropub -33.831188  18.651800

# %% [markdown]
# As Seen Not a lot things are found in this neighborhood: Lets examine Street Code 7708 which is close by:

# %%
# one hot encoding
khaya_onehot = pd.get_dummies(nearby_venues[['categories']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
khaya_onehot['PostalCode'] = khayelitsha_data['PostalCode'] 

# move neighborhood column to the first column
fixed_columns = [khaya_onehot.columns[-1]] + list(khaya_onehot.columns[:-1])
khaya_onehot = khaya_onehot[fixed_columns]

khaya_onehot.head()
# Out:
#   PostalCode  American Restaurant  ...  Steakhouse  Thai Restaurant
# 0       7551                    0  ...           0                0
# 1        NaN                    0  ...           0                0
# 2        NaN                    0  ...           0                0
# 3        NaN                    0  ...           1                0
# 4        NaN                    0  ...           0                0
#
# [5 rows x 19 columns]

# %%
venues_map_khaya = folium.Map(location=[neighborhood_latitude, neighborhood_longitude], zoom_start=15) # generate map centred around khayelitsha
# add  spots to the map as red circle markers
for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='red',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map_khaya)

# display map
venues_map_khaya
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
claremont_data = df_group_streets[df_group_streets['StreetCode'] == '7708'].reset_index(drop=True)
claremont_data.head()

neighborhood_latitude = claremont_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = claremont_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = claremont_data.loc[0, 'Neigbourhood'] # neighborhood area

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Southern Suburbs are -33.98406, 18.473779999999998.

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
from pandas.io.json import json_normalize
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
# <bound method NDFrame.head of                                                name  ...        lng
# 0                                     D's Speakeasy  ...  18.646246
# 1                                       Vida e café  ...  18.648543
# 2                                          Die Boer  ...  18.650528
# 3                                      Cattle Baron  ...  18.651611
# 4                                  The Olive Bistro  ...  18.651800
# 5                                              Soet  ...  18.648526
# 6                                        Bossa Nova  ...  18.649495
# 7                      Alberto's Restaurant and Pub  ...  18.648606
# 8                                 Silver Creek Spur  ...  18.647458
# 9                         Virgin Active Health Club  ...  18.647232
# 10                            Woolworths Palm Grove  ...  18.647834
# 11                                 Slug And Lettuce  ...  18.646269
# 12                        Bella Bellota Durbanville  ...  18.649672
# 13                             Checkers Durbanville  ...  18.647743
# 14                              Chocolat Café Decor  ...  18.647732
# 15                                            Wimpy  ...  18.646806
# 16                                              KFC  ...  18.649500
# 17                          Simply Asia Durbanville  ...  18.646108
# 18                                      Mugg & Bean  ...  18.647644
# 19                          Buena Vista Social Café  ...  18.647911
# 20                                    Roman's Pizza  ...  18.646523
# 21  Himalayan Asian Restaurant,Sushi Bar and Lounge  ...  18.647940
#
# [22 rows x 4 columns]>

# %% [markdown]
# Map visualization

# %%
venues_map_claremont = folium.Map(location=[neighborhood_latitude, neighborhood_longitude], zoom_start=15) # generate map centred around khayelitsha
# add  spots to the map as red circle markers
for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='red',
        fill_color='yellow',
        fill_opacity=0.6
        ).add_to(venues_map_claremont)

# display map
venues_map_claremont
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# one hot encoding
south_onehot = pd.get_dummies(nearby_venues[['categories']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
south_onehot['Neighborhood'] = claremont_data['Neigbourhood'] 

# move neighborhood column to the first column
fixed_columns = [south_onehot.columns[-1]] + list(south_onehot.columns[:-1])
south_onehot = south_onehot[fixed_columns]

south_onehot['Neighborhood'] ='Southern Suburbs'

south_onehot.head()
# Out:
#        Neighborhood  American Restaurant  ...  Steakhouse  Thai Restaurant
# 0  Southern Suburbs                    0  ...           0                0
# 1  Southern Suburbs                    0  ...           0                0
# 2  Southern Suburbs                    0  ...           0                0
# 3  Southern Suburbs                    0  ...           1                0
# 4  Southern Suburbs                    0  ...           0                0
#
# [5 rows x 19 columns]

# %%
# one hot encoding
north_onehot = pd.get_dummies(nearby_venues[['categories']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
north_onehot['Neighborhood'] = khayelitsha_data['Neigbourhood'] 

# move neighborhood column to the first column
fixed_columns = [north_onehot.columns[-1]] + list(north_onehot.columns[:-1])
north_onehot = north_onehot[fixed_columns]
south_onehot['Neighborhood'] ='Northen Suburbs'
north_onehot.head()
# Out:
#        Neighborhood  American Restaurant  ...  Steakhouse  Thai Restaurant
# 0  Northern Suburbs                    0  ...           0                0
# 1               NaN                    0  ...           0                0
# 2               NaN                    0  ...           0                0
# 3               NaN                    0  ...           1                0
# 4               NaN                    0  ...           0                0
#
# [5 rows x 19 columns]

# %%
south_grouped = south_onehot.groupby('Neighborhood').mean().reset_index()
south_grouped
# Out:
#       Neighborhood  American Restaurant  ...  Steakhouse  Thai Restaurant
# 0  Northen Suburbs                 0.05  ...         0.1             0.05
#
# [1 rows x 17 columns]

# %%
# set number of clusters
kclusters = 5

south_grouped_clustering = south_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(south_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-15804d3479b4> in <module>()
#       5
#       6 # run k-means clustering
# ----> 7 kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(south_grouped_clustering)
#       8
#       9 # check cluster labels generated for each row in the dataframe
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     861         if _num_samples(X) < self.n_clusters:
#     862             raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
# --> 863                 _num_samples(X), self.n_clusters))
#     864
#     865         tol = _tolerance(X, self.tol)
#
# ValueError: n_samples=1 should be >= n_clusters=5
